# %%
import importlib
import adaptive_pid_recursive_extractor
importlib.reload(adaptive_pid_recursive_extractor)
# Out:
# <module 'adaptive_pid_recursive_extractor' from 'C:\\Users\\amitv\\Desktop\\PHA-Pro\\P&ID_agent\\P&ID_agent\\adaptive_pid_recursive_extractor.py'>

# %%
from adaptive_pid_recursive_extractor import run_on_image
import json
from PIL import Image

image=Image.open("123_page-0001.jpg")
result=await run_on_image(image)
print(json.dumps(result,indent=2))
# Out:
# Processing 4 top-level tiles in parallel...
# Depth=0 bbox=(0, 0, 1929, 1364)
# Depth=0 bbox=(1579, 0, 3509, 1364)
# Depth=0 bbox=(0, 1116, 1929, 2480)
# Depth=0 bbox=(1579, 1116, 3509, 2480)
# {
#   "entities": [
#     {
#       "tag": "K-01",
#       "type": "equipment",
#       "description": "Compressor (partially visible label)",
#       "line_number": "",
#       "service": "Lube Oil System",
#       "local_bbox": [
#         869,
#         533,
#         999,
#         681
#       ],
#       "tile_bbox": [
#         0,
#         0,
#         1929,
#         1364
#       ],
#       "depth": 0,
#       "tile_id": 0,
#       "global_bbox": [
#         1676301,
#         727012,
#         1927071,
#         928884
#       ]
#     },
#     {
#       "tag": "K-01",
#       "type": "equipment",
#       "description": "Compressor",
#       "line_number": "",
#       "service": "",
#       "local_bbox": [
#         0.0,
#         0.5,
#         0.34,
#         0.72
#       ],
# ...
